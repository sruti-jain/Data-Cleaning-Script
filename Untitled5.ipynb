# %%
import pandas as pd
import numpy as np

df1 = pd.read_excel('C:/Users/15832/Downloads/projects/AMEX Certpro Manual Checks/Certpro Proj Docs/Python/MyData1.xlsm', sheet_name='AMEX CT', usecols=1)
df1
# Out:
#         Test Case   Result
# 0    AXP EMV 004      Fail
# 1    AXP EMV 005      Fail
# 2    AXP EMV 007   Pending
# 3    AXP EMV 010      Fail
# 4    AXP EMV 011      Pass
# 5    AXP EMV 012      Pass
# 6    AXP EMV 013      Pass
# 7    AXP EMV 014      Fail
# 8    AXP EMV 015   Pending
# 9    AXP EMV 016      Pass
# 10  AXP EMV 017.2  Pending
# 11   AXP EMV 018      Pass
# 12   AXP EMV 019      Pass
# 13   AXP EMV 020      Pass
# 14   AXP EMV 021      Pass
# 15    AXP EMV 022     Fail
# 16   AXP EMV 023      Fail
# 17   AXP EMV 024      Pass
# 18   AXP EMV 026      Pass
# 19   AXP EMV 028      Pass
# 20   AXP EMV 029      Pass
# 21   AXP EMV 030      Pass
# 22   AXP EMV 031      Pass
# 23    AXP MAG 001     Pass
# 24    AXP MAG 002     Pass
# 25    AXP RCP 001     Pass

# %%
import pandas as pd
import numpy as np

df2 = pd.read_excel('C:/Users/15832/Downloads/projects/AMEX Certpro Manual Checks/Certpro Proj Docs/Python/MyData2.xlsm', sheet_name='AMEX CT', usecols=1)
df2
# Out:
#          Test Case Result
# 0     AXP EMV 002    Fail
# 1     AXP EMV 004    Pass
# 2     AXP EMV 005    Pass
# 3     AXP EMV 007    Pass
# 4     AXP EMV 010    Pass
# 5     AXP EMV 011    Pass
# 6     AXP EMV 012    Pass
# 7     AXP EMV 013    Pass
# 8     AXP EMV 014    Pass
# 9     AXP EMV 015    Pass
# 10    AXP EMV 016    Pass
# 11  AXP EMV 017.2    Pass
# 12    AXP EMV 018    Pass
# 13    AXP EMV 019    Pass
# 14    AXP EMV 020    Pass
# 15    AXP EMV 021    Pass
# 16    AXP EMV 022    Pass
# 17    AXP EMV 023    Pass
# 18    AXP EMV 024    Pass
# 19    AXP EMV 026    Pass
# 20    AXP EMV 028    Pass
# 21    AXP EMV 029    Fail
# 22    AXP EMV 030    Pass
# 23    AXP EMV 031    Pass
# 24     AXP MAG 001   Pass
# 25     AXP MAG 002   Pass
# 26     AXP RCP 001   Pass

# %%
#df=pd.concat(df1, df2)
#df = pd.merge(df1, df2, on=['Test Case'], how='inner')
frames = [df1, df2]

df = pd.concat(frames)

df
# Out:
#          Test Case   Result
# 0     AXP EMV 004      Fail
# 1     AXP EMV 005      Fail
# 2     AXP EMV 007   Pending
# 3     AXP EMV 010      Fail
# 4     AXP EMV 011      Pass
# 5     AXP EMV 012      Pass
# 6     AXP EMV 013      Pass
# 7     AXP EMV 014      Fail
# 8     AXP EMV 015   Pending
# 9     AXP EMV 016      Pass
# 10   AXP EMV 017.2  Pending
# 11    AXP EMV 018      Pass
# 12    AXP EMV 019      Pass
# 13    AXP EMV 020      Pass
# 14    AXP EMV 021      Pass
# 15     AXP EMV 022     Fail
# 16    AXP EMV 023      Fail
# 17    AXP EMV 024      Pass
# 18    AXP EMV 026      Pass
# 19    AXP EMV 028      Pass
# 20    AXP EMV 029      Pass
# 21    AXP EMV 030      Pass
# 22    AXP EMV 031      Pass
# 23     AXP MAG 001     Pass
# 24     AXP MAG 002     Pass
# 25     AXP RCP 001     Pass
# 0     AXP EMV 002      Fail
# 1     AXP EMV 004      Pass
# 2     AXP EMV 005      Pass
# 3     AXP EMV 007      Pass
# 4     AXP EMV 010      Pass
# 5     AXP EMV 011      Pass
# ...

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
path = os.getcwd()
os.chdir('C:/Users/15832/Downloads/projects/AMEX Certpro Manual Checks/Certpro Proj Docs/Python')
files = os.listdir(path)
files
df = pd.DataFrame()
for f in files:
    data = pd.read_excel(f, 'AMEX CT', usecols=1)
    df = df.append(data)
    df = df.groupby(['Test Case', 'Result']).size().reset_index(name='Pass or Fail Count')
df  
pivot_df = df.pivot(index='Test Case', columns='Result', values='Pass or Fail Count')
pivot_df
colors = ["#3cb371", "#ff0000"]
pivot_df.loc[:,['Pass','Fail']].plot.bar(stacked=True, color=colors, figsize=(10,7))
#df.plot.bar(stacked = True, figsize=(20,10),x='Test Case', y='Pass or Fail Count')
#plot = df.plot(kind='bar',stacked=True,title="Total Test Cases Pass Vs Fail",x='Test Case', y='Pass or Fail Count', figsize=(20,10))
#plot.set_xlabel("Test Case")
#plot.set_ylabel("Pass or Fail Count")
#plot.legend(['Total', 'Pass', 'Fail'])
#plt.show()
#ax = df.plot.bar(x='Test Case', stacked=True, figsize=(20,10))

    #df.plot.bar(stacked=True, x='Test Case', y='Pass or Fail Count', figsize=(50,20))
    #df.plot(figsize=(20,10))
#plt.savefig('stacked.png')
# Out:
# C:\Users\15832\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
